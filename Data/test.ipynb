# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./LPPL_AI_SNP.csv')
df.head()
# Out:
#          Date        Close       dtc        ai     dtcai   color
# 0  2019-01-02  2510.030029  0.762600  0.588972  0.449150  orange
# 1  2019-01-03  2447.889893  0.622811  0.518768  0.323095  orange
# 2  2019-01-04  2531.939941  0.948730  0.424563  0.402795  orange
# 3  2019-01-07  2549.689941  0.795362  0.510779  0.406254  orange
# 4  2019-01-08  2574.409912  0.615829  0.850816  0.523957  orange

# %%
len(df)
# Out:
# 1510

# %%
plt.figure(figsize=(20,20))
plt.xlabel('Date')
plt.ylabel('DTCAI')
plt.plot(df['Date'].head(500),df['dtcai'].head(500))
plt.show()
